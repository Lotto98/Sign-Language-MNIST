# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
data=pd.read_parquet(os.getcwd()+"/../models/Classifier_3/stats.parquet")
data
# Out:
#      epochs  train_losses   eval_losses  current_lrs  test_accuracies  \
# 0         1  3.299554e-02  2.022749e-02      0.01000         0.542526
# 1         2  3.046743e-03  2.632821e-04      0.00999         0.898215
# 2         3  1.063999e-04  8.286394e-05      0.00998         0.900446
# 3         4  4.059693e-05  4.051210e-05      0.00997         0.893475
# 4         5  2.460424e-05  2.641428e-05      0.00996         0.892499
# ..      ...           ...           ...          ...              ...
# 995     996  4.674637e-08  6.153497e-07      0.00500         0.889849
# 996     997  4.670507e-08  6.152609e-07      0.00500         0.889849
# 997     998  4.666369e-08  6.148824e-07      0.00500         0.889849
# 998     999  4.662163e-08  6.147727e-07      0.00500         0.889849
# 999    1000  4.657626e-08  6.145386e-07      0.00500         0.889849
#
#      best_epoch
# 0          1000
# 1          1000
# 2          1000
# 3          1000
# 4          1000
# ..          ...
# 995        1000
# 996        1000
# 997        1000
# 998        1000
# 999        1000
#
# [1000 rows x 6 columns]

# %%
def plot_loss():
    
    fig,ax=plt.subplots(figsize=(20,10))
    
    #axs=[item for sublist in axs for item in sublist]
    
    ax.plot(data["epochs"],data["eval_losses"])
    ax.plot(data["epochs"],data["train_losses"])
    ax.set_ylim(0,0.00001)
        
plot_loss()

# %%
def plot_lr():
    
    fig,axs=plt.subplots(1,2, figsize=(15,15))
    
    #axs=[item for sublist in axs for item in sublist]
    
    for ax in axs:
        ax.plot(data["epochs"],data["current_lrs"])
        
plot_lr()

# %%
def plot_accuracy():
    fig,axs=plt.subplots(1,2,figsize=(25,10))
    
    #axs=[item for sublist in axs for item in sublist]
    
    for ax in axs:
        ax.plot(data["epochs"],data["test_accuracies"])
        ax.set_ylim(0.85,0.9)
        
plot_accuracy()
