# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
data=pd.read_parquet(os.getcwd()+"/../models/Classifier_2/stats.parquet")
data
# Out:
#      epochs  train_losses   eval_losses  current_lrs  test_accuracies  \
# 0         1  5.249890e-02  5.025556e-02      0.01000         0.029281
# 1         2  5.021508e-02  5.016213e-02      0.00999         0.029281
# 2         3  5.013075e-02  5.007239e-02      0.00998         0.030396
# 3         4  5.000261e-02  4.967651e-02      0.00997         0.041550
# 4         5  4.975300e-02  4.995614e-02      0.00996         0.023564
# ..      ...           ...           ...          ...              ...
# 995     996  5.688076e-08  2.110122e-07      0.00500         0.875349
# 996     997  5.682878e-08  2.108789e-07      0.00500         0.875349
# 997     998  5.677168e-08  2.107441e-07      0.00500         0.875349
# 998     999  5.671908e-08  2.106025e-07      0.00500         0.875349
# 999    1000  5.666752e-08  2.104782e-07      0.00500         0.875349
#
#      best_epoch
# 0          1000
# 1          1000
# 2          1000
# 3          1000
# 4          1000
# ..          ...
# 995        1000
# 996        1000
# 997        1000
# 998        1000
# 999        1000
#
# [1000 rows x 6 columns]

# %%
def plot_loss():
    
    fig,ax=plt.subplots(figsize=(20,10))
    
    #axs=[item for sublist in axs for item in sublist]
    
    ax.plot(data["epochs"],data["eval_losses"])
    ax.plot(data["epochs"],data["train_losses"])
    ax.set_ylim(0,0.00001)
        
plot_loss()

# %%
def plot_lr():
    
    fig,axs=plt.subplots(1,2, figsize=(15,15))
    
    #axs=[item for sublist in axs for item in sublist]
    
    for ax in axs:
        ax.plot(data["epochs"],data["current_lrs"])
        
plot_lr()

# %%
def plot_accuracy():
    fig,axs=plt.subplots(1,2,figsize=(25,10))
    
    #axs=[item for sublist in axs for item in sublist]
    
    for ax in axs:
        ax.plot(data["epochs"],data["test_accuracies"])
        ax.set_ylim(0.85,0.9)
        
plot_accuracy()
